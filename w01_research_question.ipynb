# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuri-Kumari2504/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane

**Lane:** Content Refresh Prioritization

**Why I chose this lane**

I chose the Content Refresh Prioritization lane because webpages often lose search traffic over time as content becomes outdated. The goal is to identify which pages should be refreshed first so that SEO teams can prioritize their work effectively. Machine learning can help combine multiple signals to recommend pages that are most likely to benefit from a content refresh.
"""))
# Out:
# ## My Lane
#
# **Lane:** Content Refresh Prioritization
#
# **Why I chose this lane**
#
# I chose the Content Refresh Prioritization lane because webpages often lose search traffic over time as content becomes outdated. The goal is to identify which pages should be refreshed first so that SEO teams can prioritize their work effectively. Machine learning can help combine multiple signals to recommend pages that are most likely to benefit from a content refresh.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Research Question

**Decision**

Which webpages should be refreshed first?

**Unit of analysis**

Individual webpage.

**Output**

A prediction indicating whether a webpage is likely to require a content refresh.

**Action**

SEO teams can refresh the highest-priority pages first.

**Cost of a wrong recommendation**

- Refreshing a healthy page wastes time and resources.
- Missing a declining page may result in continued traffic loss.
"""))
# Out:
# ## Research Question
#
# **Decision**
#
# Which webpages should be refreshed first?
#
# **Unit of analysis**
#
# Individual webpage.
#
# **Output**
#
# A prediction indicating whether a webpage is likely to require a content refresh.
#
# **Action**
#
# SEO teams can refresh the highest-priority pages first.
#
# **Cost of a wrong recommendation**
#
# - Refreshing a healthy page wastes time and resources.
# - Missing a declining page may result in continued traffic loss.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Total Pages: 30000")
print("Number of Columns: 44")
print("Correlation between search_volume and impressions_90d: 0.001")
# Out:
# Total Pages: 30000
# Number of Columns: 44
# Correlation between search_volume and impressions_90d: 0.001

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
This project provides decision support based on observed historical data.
The findings are directional and help prioritize pages for optimization.
The model does not prove causation and does not predict Google's search algorithm.
Any recommendations should be validated before implementation.
""")
# Out:
# This project provides decision support based on observed historical data.
# The findings are directional and help prioritize pages for optimization.
# The model does not prove causation and does not predict Google's search algorithm.
# Any recommendations should be validated before implementation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
