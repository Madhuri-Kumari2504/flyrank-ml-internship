# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuri-Kumari2504/flyrank-ml-internship/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# # Task Type: Classification
# #
# # This is a classification problem because the goal is to predict
# # whether a content item is declining or not.
# # The target is a binary label: is_declining_label.
# # This prediction helps identify content that should be refreshed.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# # Target: is_declining_label
# #
# # The model predicts whether a content item is declining.
# # This label is derived from historical performance trends.
# # Note: trend_pct and trend_direction should NOT be used as features
# # because they are used to create the target label.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# # Success Metric: F1 Score
# #
# # F1 Score balances Precision and Recall.
# # It is suitable because correctly identifying declining content
# # is more important than simply maximizing overall accuracy.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the FlyRank starter dataset
df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

# Show dataset information
print("Dataset Shape:", df.shape)

# Display first 5 rows
display(df.head())

# Show column names
print("\nColumns:")
print(df.columns.tolist())

# Unit of analysis
print("\nUnit of Analysis:")
print("One row represents one pseudonymized content item with its content and performance metrics collected over the previous 90 days.")
# Out:
# Dataset Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.columns.tolist()
# Out:
# ['content_id',
#  'client_id',
#  'search_volume',
#  'competition',
#  'competition_level',
#  'cpc',
#  'content_type',
#  'main_intent',
#  'word_count',
#  'char_count',
#  'provider_used',
#  'model_used',
#  'impressions_90d',
#  'clicks_90d',
#  'pageviews_90d',
#  'sessions_90d',
#  'users_90d',
#  'engaged_sessions_90d',
#  'ai_sessions_90d',
#  'scroll_events_90d',
#  'days_with_impressions',
#  'days_with_sessions',
#  'impressions_last_30d',
#  'clicks_last_30d',
#  'sessions_last_30d',
#  'impressions_prev_30d',
#  'clicks_prev_30d',
#  'sessions_prev_30d',
#  'content_age_days',
#  'age_tier',
#  'age_tier_order',
#  'days_since_last_update',
#  'freshness_tier',
#  'word_count_tier',
#  'char_count_tier',
#  'ctr',
#  'avg_position',
#  'engagement_rate',
#  'scroll_rate',
#  'ai_traffic_pct',
#  'impression_tier',
#  'position_tier',
#  'trend_direction',
#  'trend_pct']

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# # Machine learning is better than a fixed rule because
# # content performance depends on many interacting factors
# # such as clicks, impressions, engagement, CTR, and content characteristics.
# # A simple if-else rule cannot capture these complex relationships,
# # while ML can learn patterns from historical data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
